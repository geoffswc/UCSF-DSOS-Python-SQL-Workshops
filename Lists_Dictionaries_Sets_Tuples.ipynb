# %%
# lists
# dictionaries

# %%
# tuples
# sets (important for understanding bag-of-words model)
# strings

# %%
sentence = "Friday is today a beautiful day and what a beautiful day it is"

# %%
word_list = ['Friday', 'is', 'today', 'a', 'beautiful', 'day']

# %%
char_list = ['F', 'r', 'i', 'd', 'a', 'y']
word = 'Friday'

# %%
word[1:4]
# Out:
# 'rid'

# %%
char_list[1:4]
# Out:
# ['r', 'i', 'd']

# %%
# immutable
# mutable means you can change it without replacing it
# immutable means you can't change it, you can only replace it

# %%
char_list[2] = 'w'

# %%
print(char_list)
# Out:
# ['F', 'r', 'w', 'd', 'a', 'y']

# %%
#word[2] = 'w'

# %%
char_tuple = ('F', 'r', 'i', 'd', 'a', 'y')

# %%
char_tuple
# Out:
# ('F', 'r', 'i', 'd', 'a', 'y')

# %%
char_tuple[2]
# Out:
# 'i'

# %%
char_tuple[2] = 'w'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1286522647.py in <cell line: 0>()
# ----> 1 char_tuple[2] = 'w'
#
# TypeError: 'tuple' object does not support item assignment

# %%
word_lookup = {char_list: 'The 5th day of the week'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3458577757.py in <cell line: 0>()
# ----> 1 word_lookup = {char_list: 'The 5th day of the week'}
#
# TypeError: unhashable type: 'list'

# %%
sentence
# Out:
# 'Friday is today a beautiful day and what a beautiful day it is'

# %%
sentence = 'Friday is today a beautiful day and what a beautiful day it is'
all_words = sentence.split()

# %%
all_words
# Out:
# ['Friday',
#  'is',
#  'today',
#  'a',
#  'beautiful',
#  'day',
#  'and',
#  'what',
#  'a',
#  'beautiful',
#  'day',
#  'it',
#  'is']

# %%
word_set = set(['Friday',
 'is',
 'today',
 'a',
 'beautiful',
 'day',
 'and',
 'what',
 'a',
 'beautiful',
 'day',
 'it',
 'is'])

# %%
all_words
# Out:
# ['Friday',
#  'is',
#  'today',
#  'a',
#  'beautiful',
#  'day',
#  'and',
#  'what',
#  'a',
#  'beautiful',
#  'day',
#  'it',
#  'is']

# %%
word_set
# Out:
# {'Friday', 'a', 'and', 'beautiful', 'day', 'is', 'it', 'today', 'what'}

# %%
# a bag of words is a set
