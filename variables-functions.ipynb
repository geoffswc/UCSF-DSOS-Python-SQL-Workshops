# %%
print("hello")
# Out:
# hello

# %%
# prompt: write the word hello out to the screen
print("hello")
# Out:
# hello

# %%
(1 + 2) * (3 + 4)
# Out:
# 21

# %%
temperature = 81

# %%
temperature
# Out:
# 81

# %%
temperature + 10
# Out:
# 91

# %%
whos
# Out:
# Variable      Type    Data/Info
# -------------------------------
# temperature   int     81

# %%
temperature = 71
temperature = temperature + 10
print(temperature)
# Out:
# 81

# %%
temperature = 71

# %%
print(temperature)
# Out:
# 71

# %%
temperature = "Seventy-One"

# %%
temperature + " 10"
# Out:
# 'Seventy-One 10'

# %%
whos
# Out:
# Variable      Type    Data/Info
# -------------------------------
# temperature   str     Seventy-One

# %%
temperature = 61
humidity = .7
day = "Wednesday"

# %%
whos
# Out:
# Variable      Type     Data/Info
# --------------------------------
# day           str      Wednesday
# humidity      float    0.7
# temperature   int      61

# %%
print(day)
print(humidity + temperature)
# Out:
# Wednesday
# 61.7

# %%
temperature = "61"
humidity = .7
day = "Wednesday"

# %%
print(day)
print(day + " " + humidity + " " + temperature)
# Out:
# Wednesday
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-7baf690e10a8> in <cell line: 0>()
#       1 print(day)
# ----> 2 print(day + " " + humidity + " " + temperature)
#
# TypeError: can only concatenate str (not "float") to str

# %%
temperature = int("61")
humidity = str(humidity)

# %%
whos
# Out:
# Variable      Type    Data/Info
# -------------------------------
# day           str     Wednesday
# humidity      str     0.7
# temperature   int     61
